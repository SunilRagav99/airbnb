# %%
# !pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.1/670.1 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 6.7 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient, errors

client = MongoClient("mongodb+srv://SUNIL:12345@cluster0.4p2eeut.mongodb.net/?retryWrites=true&w=majority")
db = client.sample_airbnb
col = db.listingsAndReviews

# %%
rel_data = []
for i in col.find():
    data = dict(Id = i['_id'],
                Listing_url = i['listing_url'],
                Name = i['name'],
                Description = i['description'],
                House_rules = i['house_rules'],
                Property_type = i['property_type'],
                Room_type = i['room_type'],
                Bed_type = i['bed_type'],
                Min_nights = int(i['minimum_nights']),
                Max_nights = int(i['maximum_nights']),
                Cancellation_policy = i['cancellation_policy'],
                Accomodates = i['accommodates'],
                Total_bedrooms = i.get("bedrooms"),
                Total_beds = i.get('beds'),
                Availability_365 = i['availability']['availability_365'],
                Availability_30 = i['availability']['availability_30'],
                Availability_60 = i['availability']['availability_60'],
                Availability_90 = i['availability']['availability_90'],
                Price = i['price'],
                Security_deposit = i.get('security_deposit'),
                Cleaning_fee = i.get('cleaning_fee'),
                Extra_people = i['extra_people'],
                Guests_included= i['guests_included'],
                Image_url=i["images"]["picture_url"],
                No_of_reviews = i['number_of_reviews'],
                Review_scores = i['review_scores'].get('review_scores_rating'),
                Amenities = ', '.join(i['amenities']),
                Host_id=i["host"]["host_id"],
                Host_url=i["host"]["host_url"],
                Host_name=i["host"]["host_name"],
                Host_location=i["host"]["host_location"],
                Host_about=i["host"]["host_about"],
                Host_response_time=i["host"].get("host_response_time"),
                Host_thumbnail_url=i["host"].get("host_thumbnail_url"),
                Host_picture_url=i["host"]["host_picture_url"],
                Host_neighbourhood=i["host"]["host_neighbourhood"],
                Host_response_rate=i["host"].get("host_response_rate"),
                Host_is_superhost=i["host"]["host_is_superhost"],
                Host_has_profile_pic=i["host"]["host_has_profile_pic"],
                Host_identity_verified=i["host"].get("host_identity_verified"),
                Host_listing_count=i["host"].get("host_listings_count"),
                Host_total_listing_count=i["host"].get("host_total_listings_count"),
                Host_verifications=", ".join(i["host"].get("host_verifications")),
                Street = i['address']['street'],
                Suburb =i["address"]["suburb"],
                Government_area=i["address"]["government_area"],
                Market=i["address"]["market"],
                Country = i['address']['country'],
                Country_code = i['address']['country_code'],
                Location_type = i['address']['location']['type'],
                Longitude = i['address']['location']['coordinates'][0],
                Latitude = i['address']['location']['coordinates'][1],
                Is_location_exact = i['address']['location']['is_location_exact']
    )
    rel_data.append(data)

# %%
import pandas as pd
df = pd.DataFrame(rel_data)

# %%
df
# Out:
#             Id                            Listing_url  \
# 0     10021707  https://www.airbnb.com/rooms/10021707
# 1     10030955  https://www.airbnb.com/rooms/10030955
# 2     10057447  https://www.airbnb.com/rooms/10057447
# 3     10082422  https://www.airbnb.com/rooms/10082422
# 4     10112159  https://www.airbnb.com/rooms/10112159
# ...        ...                                    ...
# 5550   9937100   https://www.airbnb.com/rooms/9937100
# 5551   9979991   https://www.airbnb.com/rooms/9979991
# 5552   9981541   https://www.airbnb.com/rooms/9981541
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    Name  \
# 0                              Private Room in Bushwick
# 1                           Apt Linda Vista Lagoa - Rio
# 2                        Modern Spacious 1 Bedroom Loft
# 3                         Nice room in Barcelona Center
# ...

# %%
print(df.shape)
# Out:
# (5555, 53)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        5555 non-null   object
#  1   Listing_url               5555 non-null   object
#  2   Name                      5555 non-null   object
#  3   Description               5555 non-null   object
#  4   House_rules               5555 non-null   object
#  5   Property_type             5555 non-null   object
#  6   Room_type                 5555 non-null   object
#  7   Bed_type                  5555 non-null   object
#  8   Min_nights                5555 non-null   int64
#  9   Max_nights                5555 non-null   int64
#  10  Cancellation_policy       5555 non-null   object
#  11  Accomodates               5555 non-null   int64
#  12  Total_bedrooms            5550 non-null   float64
# ...

# %%
df.describe().T
# Out:
#                            count          mean           std        min  \
# Min_nights                5555.0  5.564356e+00  2.261386e+01    1.00000
# Max_nights                5555.0  1.382776e+06  5.256920e+07    1.00000
# Accomodates               5555.0  3.505851e+00  2.297019e+00    1.00000
# Total_bedrooms            5550.0  1.411712e+00  1.041942e+00    0.00000
# Total_beds                5542.0  2.071454e+00  1.619660e+00    0.00000
# Availability_365          5555.0  1.731057e+02  1.398419e+02    0.00000
# Availability_30           5555.0  1.181620e+01  1.168611e+01    0.00000
# Availability_60           5555.0  2.645131e+01  2.347601e+01    0.00000
# Availability_90           5555.0  4.275806e+01  3.522690e+01    0.00000
# No_of_reviews             5555.0  2.760648e+01  4.979838e+01    0.00000
# Review_scores             4081.0  9.309924e+01  9.023483e+00   20.00000
# Host_response_rate        4167.0  9.311831e+01  1.854151e+01    0.00000
# ...

# %%
df.isna().sum()
# Out:
# Id                             0
# Listing_url                    0
# Name                           0
# Description                    0
# House_rules                    0
# Property_type                  0
# Room_type                      0
# Bed_type                       0
# Min_nights                     0
# Max_nights                     0
# Cancellation_policy            0
# Accomodates                    0
# Total_bedrooms                 5
# Total_beds                    13
# Availability_365               0
# Availability_30                0
# Availability_60                0
# Availability_90                0
# Price                          0
# Security_deposit            2084
# Cleaning_fee                1531
# Extra_people                   0
# Guests_included                0
# Image_url                      0
# No_of_reviews                  0
# Review_scores               1474
# Amenities                      0
# Host_id                        0
# ...

# %%
df['Cleaning_fee'].fillna(0, inplace=True)
df['Total_bedrooms'].fillna(0, inplace=True)
df['Total_beds'].fillna(0, inplace=True)
df['Security_deposit'].fillna(0, inplace=True)
df['Cleaning_fee'].fillna(0, inplace=True)
df["Review_scores"].fillna(0,inplace=True)
df["Host_response_time"].fillna("Not Specified",inplace=True)
df.isnull().sum()
# Out:
# Id                             0
# Listing_url                    0
# Name                           0
# Description                    0
# House_rules                    0
# Property_type                  0
# Room_type                      0
# Bed_type                       0
# Min_nights                     0
# Max_nights                     0
# Cancellation_policy            0
# Accomodates                    0
# Total_bedrooms                 0
# Total_beds                     0
# Availability_365               0
# Availability_30                0
# Availability_60                0
# Availability_90                0
# Price                          0
# Security_deposit               0
# Cleaning_fee                   0
# Extra_people                   0
# Guests_included                0
# Image_url                      0
# No_of_reviews                  0
# Review_scores                  0
# Amenities                      0
# Host_id                        0
# ...

# %%
df["Price"]=df["Price"].astype(str).astype(float)
df["Security_deposit"]=df["Security_deposit"].astype(str).astype(float)
df["Extra_people"]=df["Extra_people"].astype(str).astype(float)
df["Cleaning_fee"]=df["Cleaning_fee"].astype(str).astype(float)
df["Guests_included"]=df["Guests_included"].astype(str).astype(int)
df["Amenities"]=df["Amenities"].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        5555 non-null   object
#  1   Listing_url               5555 non-null   object
#  2   Name                      5555 non-null   object
#  3   Description               5555 non-null   object
#  4   House_rules               5555 non-null   object
#  5   Property_type             5555 non-null   object
#  6   Room_type                 5555 non-null   object
#  7   Bed_type                  5555 non-null   object
#  8   Min_nights                5555 non-null   int64
#  9   Max_nights                5555 non-null   int64
#  10  Cancellation_policy       5555 non-null   object
#  11  Accomodates               5555 non-null   int64
#  12  Total_bedrooms            5555 non-null   float64
# ...

# %%
sorted_df = df.sort_values(by="Host_total_listing_count", ascending=False)
sorted_df
# Out:
#             Id                            Listing_url  \
# 2941  25187510  https://www.airbnb.com/rooms/25187510
# 4812   5618084   https://www.airbnb.com/rooms/5618084
# 913   14993652  https://www.airbnb.com/rooms/14993652
# 2325  21977972  https://www.airbnb.com/rooms/21977972
# 668   13764334  https://www.airbnb.com/rooms/13764334
# ...        ...                                    ...
# 724   13895156  https://www.airbnb.com/rooms/13895156
# 1957   2023934   https://www.airbnb.com/rooms/2023934
# 2438  22362074  https://www.airbnb.com/rooms/22362074
# 1173  16239737  https://www.airbnb.com/rooms/16239737
# 2914  24917821  https://www.airbnb.com/rooms/24917821
#
#                                                    Name  \
# 2941  Pristine 1BR in Quartier des Spectacles by Sonder
# 4812                     Sunny 1BR in Plateau by Sonder
# 913                   Chic 2BR in The Village by Sonder
# 2325                 Smart 1BR in The Village by Sonder
# ...

# %%
for i in range(11):
    condition = (df["Host_response_rate"].isna()) & (df["Host_total_listing_count"] == i) & (df["Host_listing_count"] == i)
    df.loc[condition, "Host_response_rate"] = df.loc[condition, "Host_listing_count"].copy()

# %%
df["Host_response_rate"].fillna(1,inplace=True)

# %%
df["Host_response_rate"]=df["Host_response_rate"].astype(int)

# %%
df[["Host_response_rate","Host_total_listing_count","Host_listing_count"]]
# Out:
#       Host_response_rate  Host_total_listing_count  Host_listing_count
# 0                      1                         1                   1
# 1                      1                         1                   1
# 2                      1                         1                   1
# 3                      1                         1                   1
# 4                      2                         2                   2
# ...                  ...                       ...                 ...
# 5550                 100                        14                  14
# 5551                   1                         1                   1
# 5552                  90                         6                   6
# 5553                  99                        58                  58
# 5554                  99                        58                  58
#
# [5555 rows x 3 columns]

# %%
con=df["House_rules"]==""
df.loc[con, "House_rules"] = "Not Specified"

# %%
df["Extra_people"]=df["Extra_people"].astype(float).astype(int)

# %%
df
# Out:
#             Id                            Listing_url  \
# 0     10021707  https://www.airbnb.com/rooms/10021707
# 1     10030955  https://www.airbnb.com/rooms/10030955
# 2     10057447  https://www.airbnb.com/rooms/10057447
# 3     10082422  https://www.airbnb.com/rooms/10082422
# 4     10112159  https://www.airbnb.com/rooms/10112159
# ...        ...                                    ...
# 5550   9937100   https://www.airbnb.com/rooms/9937100
# 5551   9979991   https://www.airbnb.com/rooms/9979991
# 5552   9981541   https://www.airbnb.com/rooms/9981541
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    Name  \
# 0                              Private Room in Bushwick
# 1                           Apt Linda Vista Lagoa - Rio
# 2                        Modern Spacious 1 Bedroom Loft
# 3                         Nice room in Barcelona Center
# ...

# %%
df["Security_deposit"].isnull().sum()
# Out:
# 0

# %%
df["Is_location_exact"]=df["Is_location_exact"].map({False:"No",True:"Yes"})

# %%
con1=df["Host_about"]==""
df.loc[con1, "Host_about"] = "Not Specified"

con2=df["Host_neighbourhood"]==""
df.loc[con2, "Host_neighbourhood"] = "Not Specified"

con3=df["Name"]==""
df.loc[con3, "Name"] = "Not Specified"

con4=df["Description"]==""
df.loc[con4, "Description"] = "Not Specified"

con5=df["Amenities"]==""
df.loc[con5, "Amenities"] = "Not Specified"

con6=df["Host_location"]==""
df.loc[con6, "Host_location"] = "Not Specified"

con7=df["Host_verifications"]==""
df.loc[con7, "Host_verifications"] = "Not Specified"


con8=df["Suburb"]==""
df.loc[con8, "Suburb"] = "Not Specified"

con9=df["Market"]==""
df.loc[con9, "Market"] = "Not Specified"

# %%
for j in data.keys():
    c = 0
    con3 = df[j]
    for i in con3:
        if i =="":  
            c += 1  
    print(j, c)
# Out:
# Id 0
# Listing_url 0
# Name 0
# Description 0
# House_rules 0
# Property_type 0
# Room_type 0
# Bed_type 0
# Min_nights 0
# Max_nights 0
# Cancellation_policy 0
# Accomodates 0
# Total_bedrooms 0
# Total_beds 0
# Availability_365 0
# Availability_30 0
# Availability_60 0
# Availability_90 0
# Price 0
# Security_deposit 0
# Cleaning_fee 0
# Extra_people 0
# Guests_included 0
# Image_url 0
# No_of_reviews 0
# Review_scores 0
# Amenities 0
# Host_id 0
# Host_url 0
# Host_name 0
# Host_location 0
# Host_about 0
# Host_response_time 0
# Host_thumbnail_url 0
# Host_picture_url 0
# Host_neighbourhood 0
# Host_response_rate 0
# Host_is_superhost 0
# Host_has_profile_pic 0
# Host_identity_verified 0
# Host_listing_count 0
# Host_total_listing_count 0
# Host_verifications 0
# Street 0
# Suburb 0
# Government_area 0
# Market 0
# Country 0
# Country_code 0
# Location_type 0
# Longitude 0
# Latitude 0
# Is_location_exact 0

# %%
d=df["Host_is_superhost"]==False
df.loc[d,"Host_is_superhost"]="No"

dd=df["Host_is_superhost"]==True
df.loc[dd,"Host_is_superhost"]="Yes"

# %%
df['Host_has_profile_pic'] = df['Host_has_profile_pic'].map({False:'No',True:'Yes'})

# %%
df['Host_identity_verified'] = df['Host_identity_verified'].map({False:'No',True:'Yes'})

# %%
df
# Out:
#             Id                            Listing_url  \
# 0     10021707  https://www.airbnb.com/rooms/10021707
# 1     10030955  https://www.airbnb.com/rooms/10030955
# 2     10057447  https://www.airbnb.com/rooms/10057447
# 3     10082422  https://www.airbnb.com/rooms/10082422
# 4     10112159  https://www.airbnb.com/rooms/10112159
# ...        ...                                    ...
# 5550   9937100   https://www.airbnb.com/rooms/9937100
# 5551   9979991   https://www.airbnb.com/rooms/9979991
# 5552   9981541   https://www.airbnb.com/rooms/9981541
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    Name  \
# 0                              Private Room in Bushwick
# 1                           Apt Linda Vista Lagoa - Rio
# 2                        Modern Spacious 1 Bedroom Loft
# 3                         Nice room in Barcelona Center
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        5555 non-null   object
#  1   Listing_url               5555 non-null   object
#  2   Name                      5555 non-null   object
#  3   Description               5555 non-null   object
#  4   House_rules               5555 non-null   object
#  5   Property_type             5555 non-null   object
#  6   Room_type                 5555 non-null   object
#  7   Bed_type                  5555 non-null   object
#  8   Min_nights                5555 non-null   int64
#  9   Max_nights                5555 non-null   int64
#  10  Cancellation_policy       5555 non-null   object
#  11  Accomodates               5555 non-null   int64
#  12  Total_bedrooms            5555 non-null   float64
# ...

# %%
df.to_csv("airbnbdataset.csv",index=False)
